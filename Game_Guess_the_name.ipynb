# %%
###Choose the level of the game

list_level=["1","2","3"]
print("                 WELCOME TO THE GAME: GUESS THE NUMBER") 
print("\nEntrer 1 for Easy level \nEntrer 2 for Medium level \nEntrer 3 for Hard level")
level=input("\nChoose the level of the game: ")
while level not in list_level:
    level=input("\nThe level is not correct, choose only the number 1,2 or 3 : ")
    
if level=="1":
    print("\n           YOU CHOSE THE EASY LEVEL \n               LET'S GO")
    x=1
    y=10
    trial=5
elif level=="2":
    print("\n           YOU CHOSE THE MEDIUM LEVEL \n              LET'S GO ")
    x=10
    y=100 
    trial=7
elif level=="3":
    print("\n           YOU CHOSE THE HARD LEVEL \n                 LET'S GO")
    x=-500
    y=500
    trial=10
    
###Choose a random number (guess)
import random
#print(x,y)
number=random.randint(x,y)  

###Guess a number:
count=0
while count < trial:
    try:
        guess = int(input(f"\nGuess the number between {x} and {y} : "))
        if not x <= guess <= y:
            print("\nInvalid input! The number should be between ",x," and ",y," :  ")
        elif guess > number:
            print("\nToo high, try again. Hint: the number is less than {}.".format(guess))
        elif guess < number:
            print("\nToo low, try again. Hint: the number is greater than {}.".format(guess))
        else:
            print("\n            YOU GUESSED IT! The number was", number, "with ",count+1, "chances")
            break
        count += 1
    except ValueError:
        print("\nInvalid input! Please enter a number.")
else:
    print("\n             YOU LOST THE GAME \nYou have reached the maximum number of trial. \nThe number was", number)
# Out:
#                  WELCOME TO THE GAME: GUESS THE NUMBER
#
# Entrer 1 for Easy level
# Entrer 2 for Medium level
# Entrer 3 for Hard level
#
# Choose the level of the game: 2
#
#            YOU CHOSE THE MEDIUM LEVEL
#               LET'S GO
#
# Guess the number between 10 and 100 : 56
#
# Too high, try again. Hint: the number is less than 56.
#
# Guess the number between 10 and 100 : 50
#
# Too high, try again. Hint: the number is less than 50.
#
# Guess the number between 10 and 100 : 25
#
# Too high, try again. Hint: the number is less than 25.
#
# Guess the number between 10 and 100 : 15
#
# Too high, try again. Hint: the number is less than 15.
#
# Guess the number between 10 and 100 : 5
#
# Invalid input! The number should be between  10  and  100  :
#
# Guess the number between 10 and 100 : 10
#
# Too low, try again. Hint: the number is greater than 10.
#
# Guess the number between 10 and 100 : 13
#
# Too high, try again. Hint: the number is less than 13.
#
#              YOU LOST THE GAME
# You have reached the maximum number of chances.
# The number was 11
